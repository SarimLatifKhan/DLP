# %%
### Same code

# %%
from google.colab import drive
drive.mount('/kaggle/working/drive')

# %%
# !mkdir ~/.kaggle
# !cp /kaggle/working/drive/MyDrive/DLP project/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list

# %%
# !rm -r ~/.kaggle
# !mkdir ~/.kaggle
# !mv ./kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !pwd

# %%
# !kaggle datasets list
import shutil
import os

# %%
# !kaggle datasets download -d royaldreams/face-emotion
# !kaggle datasets download -d ananthu017/emotion-detection-fer
# !kaggle datasets download -d msambare/fer2013

# %%
# !pwd

# %%
# !unzip face-emotion.zip
# !unzip emotion-detection-fer.zip -d emotion_detection_fer
# !unzip fer2013.zip

# %% [markdown]
# ### train test merge

# %%
import os
import shutil
#Joining training data

#Happy

trainsource_dir1 = "/kaggle/working/emotion_detection_fer/train/happy"
trainsource_dir2 = "/kaggle/working/train/happy"
trainsource_dir3 = "/kaggle/working/val/val/Happy"
# trainsource_dir4 = "/kaggle/working/train/train/Happy"
train_dir = "/kaggle/working/trainmerged/Happy"

# Create the destination directory if it doesn't exist
if not os.path.exists(train_dir):
    os.makedirs(train_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(trainsource_dir1):
    shutil.copy(os.path.join(trainsource_dir1, file_name), train_dir)

# Copy the files from the second source directory to the destination directory
for file_name in os.listdir(trainsource_dir2):
    shutil.copy(os.path.join(trainsource_dir2, file_name), train_dir)


#Angry

trainsource_dir1 = "/kaggle/working/emotion_detection_fer/train/angry"
trainsource_dir2 = "/kaggle/working/train/angry"
trainsource_dir3 = "/kaggle/working/val/val/Angry"
# trainsource_dir4 = "/kaggle/working/train/train/Angry"
train_dir = "/kaggle/working/trainmerged/Angry"

# Create the destination directory if it doesn't exist
if not os.path.exists(train_dir):
    os.makedirs(train_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(trainsource_dir1):
    shutil.copy(os.path.join(trainsource_dir1, file_name), train_dir)

# Copy the files from the second source directory to the destination directory
for file_name in os.listdir(trainsource_dir2):
    shutil.copy(os.path.join(trainsource_dir2, file_name), train_dir)

#Disgust

trainsource_dir1 = "/kaggle/working/emotion_detection_fer/train/disgusted"
trainsource_dir2 = "/kaggle/working/train/disgust"
trainsource_dir3 = "/kaggle/working/val/val/Disgust"
# trainsource_dir4 = "/kaggle/working/train/train/Disgust"
train_dir = "/kaggle/working/trainmerged/Disgust"

# Create the destination directory if it doesn't exist
if not os.path.exists(train_dir):
    os.makedirs(train_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(trainsource_dir1):
    shutil.copy(os.path.join(trainsource_dir1, file_name), train_dir)

# Copy the files from the second source directory to the destination directory
for file_name in os.listdir(trainsource_dir2):
    shutil.copy(os.path.join(trainsource_dir2, file_name), train_dir)


#Fear

trainsource_dir1 = "/kaggle/working/emotion_detection_fer/train/fearful"
trainsource_dir2 = "/kaggle/working/train/fear"
trainsource_dir3 = "/kaggle/working/val/val/Fear"
# trainsource_dir4 = "/kaggle/working/train/train/Fear"
train_dir = "/kaggle/working/trainmerged/Fear"

# Create the destination directory if it doesn't exist
if not os.path.exists(train_dir):
    os.makedirs(train_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(trainsource_dir1):
    shutil.copy(os.path.join(trainsource_dir1, file_name), train_dir)

# Copy the files from the second source directory to the destination directory
for file_name in os.listdir(trainsource_dir2):
    shutil.copy(os.path.join(trainsource_dir2, file_name), train_dir)

#Neutral

trainsource_dir1 = "/kaggle/working/emotion_detection_fer/train/neutral"
trainsource_dir2 = "/kaggle/working/train/neutral"
trainsource_dir3 = "/kaggle/working/val/val/Neutral"
# trainsource_dir4 = "/kaggle/working/train/train/Neutral"
train_dir = "/kaggle/working/trainmerged/Neutral"

# Create the destination directory if it doesn't exist
if not os.path.exists(train_dir):
    os.makedirs(train_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(trainsource_dir1):
    shutil.copy(os.path.join(trainsource_dir1, file_name), train_dir)

# Copy the files from the second source directory to the destination directory
for file_name in os.listdir(trainsource_dir2):
    shutil.copy(os.path.join(trainsource_dir2, file_name), train_dir)

#Sad

trainsource_dir1 = "/kaggle/working/emotion_detection_fer/train/sad"
trainsource_dir2 = "/kaggle/working/train/sad"
trainsource_dir3 = "/kaggle/working/val/val/Sad"
# trainsource_dir4 = "/kaggle/working/train/train/Sad"
train_dir = "/kaggle/working/trainmerged/Sad"

# Create the destination directory if it doesn't exist
if not os.path.exists(train_dir):
    os.makedirs(train_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(trainsource_dir1):
    shutil.copy(os.path.join(trainsource_dir1, file_name), train_dir)

# Copy the files from the second source directory to the destination directory
for file_name in os.listdir(trainsource_dir2):
    shutil.copy(os.path.join(trainsource_dir2, file_name), train_dir)

#Surprise

trainsource_dir1 = "/kaggle/working/emotion_detection_fer/train/surprised"
trainsource_dir2 = "/kaggle/working/train/surprise"
trainsource_dir3 = "/kaggle/working/val/val/Surprise"
# trainsource_dir4 = "/kaggle/working/train/train/Surprise"
train_dir = "/kaggle/working/trainmerged/Surprise"

# Create the destination directory if it doesn't exist
if not os.path.exists(train_dir):
    os.makedirs(train_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(trainsource_dir1):
    shutil.copy(os.path.join(trainsource_dir1, file_name), train_dir)

# Copy the files from the second source directory to the destination directory
for file_name in os.listdir(trainsource_dir2):
    shutil.copy(os.path.join(trainsource_dir2, file_name), train_dir)

# %%
import os
import shutil
#Joining test data

#Happy

testsource_dir1 = "/kaggle/working/test/happy"
testsource_dir2 = "/kaggle/working/emotion_detection_fer/test/happy"
test_dir = "/kaggle/working/testmerged/Happy"

# Create the destination directory if it doesn't exist
if not os.path.exists(test_dir):
    os.makedirs(test_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(testsource_dir1):
    shutil.copy(os.path.join(testsource_dir1, file_name), test_dir)

#Angry

testsource_dir1 = "/kaggle/working/test/angry"
testsource_dir2 = "/kaggle/working/emotion_detection_fer/test/angry"
test_dir = "/kaggle/working/testmerged/Angry"

# Create the destination directory if it doesn't exist
if not os.path.exists(test_dir):
    os.makedirs(test_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(testsource_dir1):
    shutil.copy(os.path.join(testsource_dir1, file_name), test_dir)

#Disgust

testsource_dir1 = "/kaggle/working/test/disgust"
testsource_dir2 = "/kaggle/working/emotion_detection_fer/test/disgusted"
test_dir = "/kaggle/working/testmerged/Disgust"

# Create the destination directory if it doesn't exist
if not os.path.exists(test_dir):
    os.makedirs(test_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(testsource_dir1):
    shutil.copy(os.path.join(testsource_dir1, file_name), test_dir)


#Fear

testsource_dir1 = "/kaggle/working/test/fear"
testsource_dir2 = "/kaggle/working/emotion_detection_fer/test/fearful"
test_dir = "/kaggle/working/testmerged/Fear"

# Create the destination directory if it doesn't exist
if not os.path.exists(test_dir):
    os.makedirs(test_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(testsource_dir1):
    shutil.copy(os.path.join(testsource_dir1, file_name), test_dir)

#Neutral

testsource_dir1 = "/kaggle/working/test/neutral"
testsource_dir2 = "/kaggle/working/emotion_detection_fer/test/neutral"
test_dir = "/kaggle/working/testmerged/Neutral"

# Create the destination directory if it doesn't exist
if not os.path.exists(test_dir):
    os.makedirs(test_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(testsource_dir1):
    shutil.copy(os.path.join(testsource_dir1, file_name), test_dir)

#Sad

testsource_dir1 = "/kaggle/working/test/sad"
testsource_dir2 = "/kaggle/working/emotion_detection_fer/test/sad"
test_dir = "/kaggle/working/testmerged/Sad"

# Create the destination directory if it doesn't exist
if not os.path.exists(test_dir):
    os.makedirs(test_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(testsource_dir1):
    shutil.copy(os.path.join(testsource_dir1, file_name), test_dir)

#Surprise

testsource_dir1 = "/kaggle/working/test/surprise"
testsource_dir2 = "/kaggle/working/emotion_detection_fer/test/surprised"
test_dir = "/kaggle/working/testmerged/Surprise"

# Create the destination directory if it doesn't exist
if not os.path.exists(test_dir):
    os.makedirs(test_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(testsource_dir1):
    shutil.copy(os.path.join(testsource_dir1, file_name), test_dir)

# %% [markdown]
# ---

# %% [markdown]
# ## using pretrained models

# %% [markdown]
# ### libraries

# %%
# !pip install tensorflow
# !pip install keras
# !pip install tensorflow==2.12.0
# !pip install keras==2.12.0
# !pip install pixellib

# %%
pip install --upgrade keras

# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import tensorflow as tf
import keras
from keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten,Dense,Dropout,BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils  #esehi dekhrai

import cv2
from keras import regularizers
from keras.applications import VGG16, InceptionResNetV2
from keras.optimizers import Adam,RMSprop,SGD,Adamax

from PIL import Image
import matplotlib.pyplot as plt
from keras.models import load_model

# %% [markdown]
# ### VGG19

# %%
from keras.preprocessing.image import ImageDataGenerator
img_size = 48 #original size of the image
test_dir = "/kaggle/working/testmerged"
train_dir = "/kaggle/working/trainmerged"

train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)


# Flow training images in batches of 128 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
    directory=train_dir,
    target_size=(img_size, img_size),
    batch_size=256,
    color_mode="rgb",
    class_mode='categorical',
    subset='training'
)

# Flow validation images in batches of 128 using train_datagen generator
validation_generator = train_datagen.flow_from_directory(
    directory=train_dir,
    target_size=(img_size, img_size),
    batch_size=256,
    color_mode="rgb",
    class_mode='categorical',
    subset='validation'
)

# Flow test images in batches of 128 using test_datagen generator
test_generator = test_datagen.flow_from_directory(
    directory=test_dir,
    target_size=(img_size, img_size),
    batch_size=256,
    color_mode="rgb",
    class_mode='categorical'
)
# Out:
# Found 45936 images belonging to 7 classes.
# Found 11482 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
import keras.backend as K

# Clear the Keras session
K.clear_session()


from keras.applications import VGG19
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D, Dropout
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau

# Load the pre-trained VGG16 model without the top (classification) layer
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(img_size, img_size, 3))

# Freeze the layers in the base model except the last few
for layer in base_model.layers[:-5]:
    layer.trainable = False

# Add your own classification layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)  # Increased dropout for regularization
predictions = Dense(7, activation='softmax')(x)
# Out:
# ...
# 80134624/80134624 [==============================] - 0s 0us/step

# %%
# Combine the base model with your classification layers
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model with a lower learning rate
optimizer = Adam(lr=0.0001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print("Total layers in the base model:", len(base_model.layers))

print(model.summary())
# Out:
# Total layers in the base model: 22
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 48, 48, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 48, 48, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 24, 24, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 24, 24, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 24, 24, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 12, 12, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 12, 12, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 6, 6, 256)         0
#
# ...

# %%
from keras.callbacks import EarlyStopping

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=32,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    callbacks=[early_stopping]  # Include the early stopping callback here
)

# Evaluate the model on the test set
loss, accuracy = model.evaluate(test_generator, steps=test_generator.samples // test_generator.batch_size)
print(f"Loss: {loss}, Accuracy: {accuracy}")
# Out:
# Epoch 1/32
# 179/179 [==============================] - 1090s 6s/step - loss: 1.6406 - accuracy: 0.3540 - val_loss: 1.4709 - val_accuracy: 0.4428
# Epoch 2/32
# 179/179 [==============================] - 1085s 6s/step - loss: 1.4592 - accuracy: 0.4427 - val_loss: 1.4367 - val_accuracy: 0.4508
# Epoch 3/32
# 179/179 [==============================] - 1037s 6s/step - loss: 1.3742 - accuracy: 0.4815 - val_loss: 1.3416 - val_accuracy: 0.4884
# Epoch 4/32
# 179/179 [==============================] - 1083s 6s/step - loss: 1.3153 - accuracy: 0.5045 - val_loss: 1.3041 - val_accuracy: 0.5034
# Epoch 5/32
# 179/179 [==============================] - 1061s 6s/step - loss: 1.2603 - accuracy: 0.5255 - val_loss: 1.2481 - val_accuracy: 0.5289
# Epoch 6/32
# 179/179 [==============================] - 1003s 6s/step - loss: 1.2153 - accuracy: 0.5457 - val_loss: 1.2140 - val_accuracy: 0.5458
# Epoch 7/32
# ...

# %%
# Save the model
model.save('emotion_classification_model.h5')

# %% [markdown]
# ---

# %% [markdown]
# ### TESTING

# %%
 
# Load the saved model
model = load_model('/kaggle/working/emotion_classification_model.h5')

# %%
label_dict = {0:'Angry',1:'Disgust',2:'Fear',3:'Happy',4:'Neutral',5:'Sad',6:'Surprise'}

# %%
img_path = "/kaggle/working/testmerged/Happy/PublicTest_82930379.jpg"
img = Image.open(img_path).resize((48, 48)).convert('L')
img = np.array(img)
plt.imshow(img, cmap="gray")
print(img.shape) #prints (48,48) that is the shape of our image
from tensorflow.keras.preprocessing import image

# Load the image and resize it to 48x48 pixels

img1 = image.load_img(img_path, target_size=(48, 48))

# Convert the image to a numpy array and normalize it
img_array = image.img_to_array(img1) / 255.0

# Add a batch dimension
img_array = np.expand_dims(img_array, axis=0)

# Get the model's prediction
result = model.predict(img_array)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])
plt.show()
# Out:
# (48, 48)
# 1/1 [==============================] - 0s 56ms/step
# [7.79619e-05, 6.655632e-07, 0.00010755797, 0.992396, 0.00708406, 0.00027483943, 5.887483e-05]
# Happy

# %%
from PIL import Image
import matplotlib.pyplot as plt


img_path = "/kaggle/working/testmerged/Angry/PublicTest_67751726.jpg"
img = Image.open(img_path).resize((48, 48)).convert('L')
img = np.array(img)
plt.imshow(img, cmap="gray")
print(img.shape) #prints (48,48) that is the shape of our image
from tensorflow.keras.preprocessing import image

# Load the image and resize it to 48x48 pixels

img1 = image.load_img(img_path, target_size=(48, 48))

# Convert the image to a numpy array and normalize it
img_array = image.img_to_array(img1) / 255.0

# Add a batch dimension
img_array = np.expand_dims(img_array, axis=0)

# Get the model's prediction
result = model.predict(img_array)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])
plt.show()
# Out:
# (48, 48)
# 1/1 [==============================] - 0s 37ms/step
# [0.9325789, 0.0005405813, 0.0035915582, 0.0014438899, 0.012522662, 0.049097497, 0.00022492377]
# Angry

# %%
from PIL import Image
import matplotlib.pyplot as plt


img_path = "/kaggle/working/testmerged/Surprise/PrivateTest_90653008.jpg"
img = Image.open(img_path).resize((48, 48)).convert('L')
img = np.array(img)
plt.imshow(img, cmap="gray")
print(img.shape) #prints (48,48) that is the shape of our image
from tensorflow.keras.preprocessing import image

# Load the image and resize it to 48x48 pixels

img1 = image.load_img(img_path, target_size=(48, 48))

# Convert the image to a numpy array and normalize it
img_array = image.img_to_array(img1) / 255.0

# Add a batch dimension
img_array = np.expand_dims(img_array, axis=0)

# Get the model's prediction
result = model.predict(img_array)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])
plt.show()
# Out:
# (48, 48)
# 1/1 [==============================] - 0s 35ms/step
# [0.0083883675, 0.00016534499, 0.067437656, 0.0025357418, 0.0019652531, 0.000515108, 0.9189925]
# Surprise

# %%
from PIL import Image
import matplotlib.pyplot as plt


img_path = "/kaggle/working/testmerged/Neutral/PublicTest_15640368.jpg"
img = Image.open(img_path).resize((48, 48)).convert('L')
img = np.array(img)
plt.imshow(img, cmap="gray")
print(img.shape) #prints (48,48) that is the shape of our image
from tensorflow.keras.preprocessing import image

# Load the image and resize it to 48x48 pixels

img1 = image.load_img(img_path, target_size=(48, 48))

# Convert the image to a numpy array and normalize it
img_array = image.img_to_array(img1) / 255.0

# Add a batch dimension
img_array = np.expand_dims(img_array, axis=0)

# Get the model's prediction
result = model.predict(img_array)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])
plt.show()
# Out:
# (48, 48)
# 1/1 [==============================] - 0s 40ms/step
# [0.00014747705, 8.42983e-07, 0.00014298166, 1.0240237e-05, 0.9991235, 0.00055156474, 2.3393864e-05]
# Neutral

# %%
from PIL import Image
import matplotlib.pyplot as plt


img_path = "/kaggle/working/testmerged/Disgust/PrivateTest_4396496.jpg"
img = Image.open(img_path).resize((48, 48)).convert('L')
img = np.array(img)
plt.imshow(img, cmap="gray")
print(img.shape) #prints (48,48) that is the shape of our image
from tensorflow.keras.preprocessing import image

# Load the image and resize it to 48x48 pixels

img1 = image.load_img(img_path, target_size=(48, 48))

# Convert the image to a numpy array and normalize it
img_array = image.img_to_array(img1) / 255.0

# Add a batch dimension
img_array = np.expand_dims(img_array, axis=0)

# Get the model's prediction
result = model.predict(img_array)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])
plt.show()
# Out:
# (48, 48)
# 1/1 [==============================] - 0s 39ms/step
# [6.5171594e-06, 0.99996614, 2.1264357e-06, 2.0024625e-05, 2.8661707e-06, 2.0760206e-06, 2.6278082e-07]
# Disgust

# %%
from PIL import Image
import matplotlib.pyplot as plt


img_path = "/kaggle/working/testmerged/Fear/PublicTest_31261199.jpg"
img = Image.open(img_path).resize((48, 48)).convert('L')
img = np.array(img)
plt.imshow(img, cmap="gray")
print(img.shape) #prints (48,48) that is the shape of our image
from tensorflow.keras.preprocessing import image

# Load the image and resize it to 48x48 pixels

img1 = image.load_img(img_path, target_size=(48, 48))

# Convert the image to a numpy array and normalize it
img_array = image.img_to_array(img1) / 255.0

# Add a batch dimension
img_array = np.expand_dims(img_array, axis=0)

# Get the model's prediction
result = model.predict(img_array)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])
plt.show()
# Out:
# (48, 48)
# 1/1 [==============================] - 0s 38ms/step
# [0.09848059, 0.00010688039, 0.4145725, 0.00215999, 0.014654983, 0.46626914, 0.0037559236]
# Sad

# %%
from PIL import Image
import matplotlib.pyplot as plt


img_path = "/kaggle/working/testmerged/Fear/PublicTest_24478472.jpg"
img = Image.open(img_path).resize((48, 48)).convert('L')
img = np.array(img)
plt.imshow(img, cmap="gray")
print(img.shape) #prints (48,48) that is the shape of our image
from tensorflow.keras.preprocessing import image

# Load the image and resize it to 48x48 pixels

img1 = image.load_img(img_path, target_size=(48, 48))

# Convert the image to a numpy array and normalize it
img_array = image.img_to_array(img1) / 255.0

# Add a batch dimension
img_array = np.expand_dims(img_array, axis=0)

# Get the model's prediction
result = model.predict(img_array)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])
plt.show()
# Out:
# (48, 48)
# 1/1 [==============================] - 0s 38ms/step
# [0.004283799, 0.00013920329, 0.42391253, 0.01980433, 0.20028226, 0.08455754, 0.2670204]
# Fear

# %%
from PIL import Image
import matplotlib.pyplot as plt


img_path = "/kaggle/working/testmerged/Sad/PublicTest_90532579.jpg"
img = Image.open(img_path).resize((48, 48)).convert('L')
img = np.array(img)
plt.imshow(img, cmap="gray")
print(img.shape) #prints (48,48) that is the shape of our image
from tensorflow.keras.preprocessing import image

# Load the image and resize it to 48x48 pixels

img1 = image.load_img(img_path, target_size=(48, 48))

# Convert the image to a numpy array and normalize it
img_array = image.img_to_array(img1) / 255.0

# Add a batch dimension
img_array = np.expand_dims(img_array, axis=0)

# Get the model's prediction
result = model.predict(img_array)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])
plt.show()
# Out:
# (48, 48)
# 1/1 [==============================] - 0s 37ms/step
# [0.30324206, 0.003400726, 0.06556297, 0.030880548, 0.010233092, 0.5832568, 0.003423777]
# Sad

# %%
from PIL import Image
import matplotlib.pyplot as plt


img_path = "/kaggle/working/testmerged/Angry/PublicTest_84366.jpg"
img = Image.open(img_path).resize((48, 48)).convert('L')
img = np.array(img)
plt.imshow(img, cmap="gray")
print(img.shape) #prints (48,48) that is the shape of our image
from tensorflow.keras.preprocessing import image

# Load the image and resize it to 48x48 pixels

img1 = image.load_img(img_path, target_size=(48, 48))

# Convert the image to a numpy array and normalize it
img_array = image.img_to_array(img1) / 255.0

# Add a batch dimension
img_array = np.expand_dims(img_array, axis=0)

# Get the model's prediction
result = model.predict(img_array)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(label_dict[img_index])
plt.show()
# Out:
# (48, 48)
# 1/1 [==============================] - 0s 35ms/step
# [0.99589765, 1.6293528e-05, 0.0010334165, 1.9456476e-05, 0.00043661564, 0.0025850323, 1.1490614e-05]
# Angry

# %%
y_pred = model.predict(test_generator)

# Get the class with the highest probability for each sample
y_pred_labels = []
for i in y_pred:
    y_pred_labels.append(np.argmax(i))

y_actual = test_generator.classes[test_generator.index_array]

from sklearn import metrics
cm = metrics.confusion_matrix(y_actual, y_pred_labels)
disp = metrics.ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
# Out:
# 29/29 [==============================] - 66s 2s/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_actual, y_pred_labels, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.1231    0.1534    0.1366       958
#            1     0.0000    0.0000    0.0000       111
#            2     0.1237    0.1074    0.1150      1024
#            3     0.2439    0.2317    0.2376      1774
#            4     0.1725    0.1873    0.1796      1233
#            5     0.1676    0.1684    0.1680      1247
#            6     0.1283    0.1155    0.1216       831
#
#     accuracy                         0.1679      7178
#    macro avg     0.1370    0.1377    0.1369      7178
# weighted avg     0.1680    0.1679    0.1675      7178

# %%
train_loss, train_acc = model.evaluate(train_generator)
val_loss, val_acc   = model.evaluate(validation_generator)
test_loss, test_acc   = model.evaluate(test_generator)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}, testing accuracy = {:.2f}".format(train_acc*100, val_acc*100, test_acc*100))
# Out:
# ...
# 29/29 [==============================] - 65s 2s/step - loss: 1.6103 - accuracy: 0.5570
# final train accuracy = 90.26 , validation accuracy = 83.71, testing accuracy = 55.70

# %%
model.save_weights('model_emotion_classification_weights.h5')
